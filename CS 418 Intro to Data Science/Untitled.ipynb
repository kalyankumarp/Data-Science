# %%
import requests
from bs4 import BeautifulSoup
import urllib.request
import re
import time

# %%
url  = "https://cs.uic.edu/previous-course-lists/"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '  \n<!doctype html>\n<!--[if lt IE 7]><html class="no-js ie ie6 lt-ie9 lt-ie8 lt-ie7" lang="en-US"> <![endif]-->\n<!--[if IE 7]><html class="no-js ie ie7 lt-ie9 lt-ie8" lang="en-US"> <![endif]-->\n<!--[if IE 8]><html class="no-js ie ie8 lt-ie9" lang="en-US"> <![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="en-US"> <!--<![endif]-->\n\n    <head>\n\n    <!-- Google Tag Manager -->\n    <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\': new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n                j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);})\n                (window,document,\'script\',\'dataLayer\',\'GTM-W2Q8D2K\');\n    </script>\n    <!-- End Google Tag Manager -->\n\n        <title>\n                            Previous Course Lists | Department of Computer Science | University of Illinois at Chicago\n    
# ...

# %%
soup = BeautifulSoup(response.text, "html.parser")
soup
# Out:
# <!DOCTYPE doctype html>
#
# <!--[if lt IE 7]><html class="no-js ie ie6 lt-ie9 lt-ie8 lt-ie7" lang="en-US"> <![endif]-->
# <!--[if IE 7]><html class="no-js ie ie7 lt-ie9 lt-ie8" lang="en-US"> <![endif]-->
# <!--[if IE 8]><html class="no-js ie ie8 lt-ie9" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--><html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})
#                 (window,document,'script','dataLayer','GTM-W2Q8D2K');
#     </script>
# <!-- End Google Tag Manager -->
# <title>
#                             Previous Course Lists | Department of Computer Science | University of Illinois at Chicago
#                     </title>
# ...

# %%
soup.findAll("a")
# Out:
# [<a href="#article">Skip to the content of this page</a>,
#  <a class="_primary-menu" href="#menu-main">the main menu</a>,
#  <a class="_search" href="#search">the site search form</a>,
#  <a class="_home" href="https://cs.uic.edu">the site home page</a>,
#  <a class="uic-logo-icon eyebrow-mobile-logo__uic-logo" href="http://uic.edu">
#  <svg aria-label="UIC.edu home" viewbox="0 0 55 55" xmlns="http://www.w3.org/2000/svg">
#  <title>UIC Logo</title>
#  <circle class="_circle" cx="27" cy="27" fill="none" r="25"></circle>
# ...

# %%
data = soup.findAll("a", href = re.compile("TA.pdf"))
data
# Out:
# [<a href="https://www.cs.uic.edu/~grad/2019SpringTA.pdf" rel="noopener" target="_blank">Spring 2019</a>,
#  <a href="https://www.cs.uic.edu/~grad/2018FallTA.pdf" rel="noopener" target="_blank">Fall 2018</a>,
#  <a href="https://www.cs.uic.edu/~grad/2018SummerTA.pdf" rel="noopener" target="_blank">Summer 2018</a>,
#  <a href="https://www.cs.uic.edu/~grad/2018SpringTA.pdf" rel="noopener" target="_blank">Spring 2018</a>,
#  <a href="https://www.cs.uic.edu/~grad/2017FallTA.pdf" rel="noopener" target="_blank">Fall 2017</a>,
#  <a href="https://www.cs.uic.edu/~grad/2017SummerTA.pdf" rel="noopener" target="_blank">Summer 2017</a>,
#  <a href="https://www.cs.uic.edu/~grad/2017SpringTA.pdf" rel="noopener noreferrer" target="_blank">Spring 2017</a>,
#  <a href="https://www.cs.uic.edu/~grad/2016FallTA.pdf" rel="noopener noreferrer" target="_blank">Fall 2016</a>,
#  <a href="https://www.cs.uic.edu/~grad/2016SummerTA.pdf" rel="noopener noreferrer" target="_blank">Summer 2016</a>,
# ...

# %%
d = data[0]["href"]
urllib.request.urlretrieve(d, "./2k19SpringTA.pdf")
# Out:
# ('./2k19SpringTA.pdf', <http.client.HTTPMessage at 0x22dbad3fbe0>)
